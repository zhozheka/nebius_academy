# %%
import os
from llm import get_client, summarize_repo_with_retries
from features import build_repo_profile

# %%
os.environ['NEBIUS_API_KEY'] = "v1.CmQKHHN0YXRpY2tleS1lMDBubmp3bm52ZWdmOW1xcjESIXNlcnZpY2VhY2NvdW50LWUwMHhycnl0eWU5NTlhMDZqZTIMCIm28swGENCekq0COgwIiLmKmAcQgI-OxwJAAloDZTAw.AAAAAAAAAAEDvlmf4zvsU99xk2-GEj7IdhuDXTD_ImLWbB4yDuBWznxcvkyhoxr6rhO9bbOOk0Wbpjh_Ire5q-j68lv22B8P"

# %%
repo_dir = '/Users/evgeny-home/repos/linux'

# %%
repo_profile = build_repo_profile(repo_dir)

# %%
client = get_client()
result = summarize_repo_with_retries(client, repo_profile)
result.model_dump()
# Out:
# {'summary': 'The Linux kernel is the core of any Linux operating system. It manages hardware, system resources, and provides fundamental services for all other software. This repository contains the complete source code for the Linux kernel, including core kernel subsystems, device drivers, architecture-specific code, and various tools and documentation.',
#  'technologies': ['C',
#   'Assembly',
#   'Shell Script',
#   'Makefile',
#   'Python',
#   'Perl',
#   'Rust'],
#  'structure': 'The Linux kernel repository is organized into several key directories: arch/ contains architecture-specific code for various platforms (x86, ARM, etc.), drivers/ houses device drivers organized by device type, fs/ contains filesystem implementations, include/ holds header files, kernel/ contains core kernel subsystems, mm/ handles memory management, net/ implements networking protocols, and tools/ provides various development and debugging utilities. Additional directories include documentation, cryptographic implementations, and virtualization support.'}
